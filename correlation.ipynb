# %%
# %run proclus.ipynb
# %run plotter.ipynb
# %run arffreader.ipynb
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
#import adjrand

# Test to see if there is a correlation between the
# proclus objective function and the adjusted rand index

X, sup = readarff("data/highdataproclus.arff")

NRUNS = 15

objs = np.zeros(NRUNS) # objective function results
adjs = np.zeros(NRUNS) # adjusted rand index results

print ("Beginning runs...")

for i in xrange(NRUNS):
	rseed = np.random.randint(low = 0, high = 1239831)
	print(">>> Run %d/%d using seed %d" % (i + 1, NRUNS, rseed))
	M, D, A = proclus(X, k = 7, l = 2, seed = rseed)
	objs[i] = evaluateClusters(X, A, D, M)
	#adjs[i] = adjrand.computeAdjustedRandIndex(A, sup)

print("Finished runs...")

sidx = np.argsort(objs)

plt.clf()
plt.plot(objs[sidx], adjs[sidx], 'bo-')
plt.xlabel("Objective function results")
plt.ylabel("Adjusted Rand Index")
plt.show()
plt.draw()

#print "Pearson correlation: %.4f" % pearsonr(objs[sidx], adjs[sidx])[0]
# Out:
# Beginning runs...
# >>> Run 1/15 using seed 23902
# bad medoids:
# [592, 1403, 631]
# old mcurr:
# [ 576  592  950 1630  925 1403  631]
# new mcurr:
# [ 576  742  925  950 1115 1630 1789]
# finished iter: 1
# bad medoids:
# [1115]
# old mcurr:
# [ 576  742  925  950 1115 1630 1789]
# new mcurr:
# [ 576  592  742  925  950 1630 1789]
# finished iter: 2
# finished iter: 3
# finished iterative phase...
# >>> Run 2/15 using seed 1034995
# bad medoids:
# [1840]
# old mcurr:
# [ 467 1728  699 1308 1123 1840  271]
# new mcurr:
# [ 271  467  699 1123 1308 1449 1728]
# finished iter: 1
# bad medoids:
# [1308]
# old mcurr:
# [ 271  467  699 1123 1308 1449 1728]
# new mcurr:
# [ 271  467  699 1123 1449 1728 1840]
# finished iter: 2
# finished iter: 3
# finished iterative phase...
# >>> Run 3/15 using seed 809210
# bad medoids:
# [211, 1902]
# old mcurr:
# [ 130  757 1902 1388   28  211  231]
# new mcurr:
# [  19   28  130  231  467  757 1388]
# finished iter: 1
# finished iter: 2
# finished iterative phase...
# >>> Run 4/15 using seed 876915
# bad medoids:
# [1403]
# old mcurr:
# [1266 1992 1403  130 1571   19  158]
# new mcurr:
# [  19  130  158  631 1266 1571 1992]
# finished iter: 1
# bad medoids:
# [130]
# old mcurr:
# [  19  130  158  631 1266 1571 1992]
# new mcurr:
# [  19  158  631 1179 1266 1571 1992]
# finished iter: 2
# finished iter: 3
# finished iterative phase...
# >>> Run 5/15 using seed 867872
# bad medoids:
# [1321, 1176]
# old mcurr:
# [1321   12 1403 1203 1176 1469 1977]
# new mcurr:
# [  12  370  631 1203 1403 1469 1977]
# finished iter: 1
# bad medoids:
# [631]
# old mcurr:
# [  12  370  631 1203 1403 1469 1977]
# new mcurr:
# [  12  370 1176 1203 1403 1469 1977]
# finished iter: 2
# bad medoids:
# [1176]
# old mcurr:
# [  12  370 1176 1203 1403 1469 1977]
# new mcurr:
# [  12  370  452 1203 1403 1469 1977]
# finished iter: 3
# finished iter: 4
# finished iterative phase...
# >>> Run 6/15 using seed 118839
# bad medoids:
# [1295, 1734]
# old mcurr:
# [1734 1354  822 1295 1610  134  257]
# new mcurr:
# [ 134  257  822  946 1354 1610 1841]
# finished iter: 1
# finished iter: 2
# finished iterative phase...
# >>> Run 7/15 using seed 700720
# bad medoids:
# [947]
# old mcurr:
# [ 947  683 1928  129  257   12 1842]
# new mcurr:
# [  12  129  180  257  683 1842 1928]
# finished iter: 1
# bad medoids:
# [257]
# old mcurr:
# [  12  129  180  257  683 1842 1928]
# new mcurr:
# [  12  129  180  251  683 1842 1928]
# finished iter: 2
# finished iter: 3
# finished iterative phase...
# >>> Run 8/15 using seed 940841
# bad medoids:
# [41]
# old mcurr:
# [  41   99  784  436  297 1116 1688]
# new mcurr:
# [  99  297  436  784 1116 1639 1688]
# finished iter: 1
# bad medoids:
# [1639]
# old mcurr:
# [  99  297  436  784 1116 1639 1688]
# new mcurr:
# [  99  297  436  784  815 1116 1688]
# finished iter: 2
# finished iter: 3
# finished iterative phase...
# >>> Run 9/15 using seed 27606
# bad medoids:
# [1403]
# old mcurr:
# [1737 1008  515 1403 1328  444 1796]
# new mcurr:
# [  85  444  515 1008 1328 1737 1796]
# finished iter: 1
# finished iter: 2
# finished iterative phase...
# >>> Run 10/15 using seed 141927
# bad medoids:
# [342]
# old mcurr:
# [ 744  342 1501 1841  207  857   34]
# new mcurr:
# [  34  207  744  857 1501 1688 1841]
# finished iter: 1
# finished iter: 2
# finished iterative phase...
# >>> Run 11/15 using seed 956103
# bad medoids:
# [1979]
# old mcurr:
# [ 231  743 1143 1979 1756  900  927]
# new mcurr:
# [ 231  743  900  927 1143 1756 1961]
# finished iter: 1
# bad medoids:
# [1143, 900]
# old mcurr:
# [ 231  743  900  927 1143 1756 1961]
# new mcurr:
# [ 231  743  927  978 1756 1776 1961]
# finished iter: 2
# finished iter: 3
# finished iterative phase...
# >>> Run 12/15 using seed 928544
# bad medoids:
# [234]
# old mcurr:
# [1328 1901  234  906  857  996 1169]
# new mcurr:
# [ 301  857  906  996 1169 1328 1901]
# finished iter: 1
# bad medoids:
# [1328]
# old mcurr:
# [ 301  857  906  996 1169 1328 1901]
# new mcurr:
# [ 301  857  900  906  996 1169 1901]
# finished iter: 2
# bad medoids:
# [301]
# old mcurr:
# [ 301  857  900  906  996 1169 1901]
# new mcurr:
# [ 712  857  900  906  996 1169 1901]
# finished iter: 3
# finished iter: 4
# finished iterative phase...
# >>> Run 13/15 using seed 1085423
# bad medoids:
# [705]
# old mcurr:
# [1053 1032 1485  591  586  489  705]
# new mcurr:
# [ 320  489  586  591 1032 1053 1485]
# finished iter: 1
# bad medoids:
# [586]
# old mcurr:
# [ 320  489  586  591 1032 1053 1485]
# new mcurr:
# [ 320  489  548  591 1032 1053 1485]
# finished iter: 2
# bad medoids:
# [548]
# old mcurr:
# [ 320  489  548  591 1032 1053 1485]
# new mcurr:
# [ 320  489  591 1032 1053 1443 1485]
# finished iter: 3
# finished iter: 4
# finished iterative phase...
# >>> Run 14/15 using seed 1183979
# bad medoids:
# [231]
# old mcurr:
# [ 410  494 1362 1140  231 1142 1175]
# new mcurr:
# [ 410  494 1140 1142 1175 1362 1772]
# finished iter: 1
# bad medoids:
# [1175]
# old mcurr:
# [ 410  494 1140 1142 1175 1362 1772]
# new mcurr:
# [ 410  494 1140 1142 1362 1375 1772]
# finished iter: 2
# bad medoids:
# [410]
# old mcurr:
# [ 410  494 1140 1142 1362 1375 1772]
# new mcurr:
# [ 300  494 1140 1142 1362 1375 1772]
# finished iter: 3
# finished iter: 4
# finished iterative phase...
# >>> Run 15/15 using seed 299396
# bad medoids:
# [878, 1908]
# old mcurr:
# [1048  878  927  510   44 1908 1243]
# new mcurr:
# [  44  231  510  897  927 1048 1243]
# finished iter: 1
# bad medoids:
# [231]
# old mcurr:
# [  44  231  510  897  927 1048 1243]
# new mcurr:
# [  44  510  897  927 1048 1243 1328]
# finished iter: 2
# bad medoids:
# [1328]
# old mcurr:
# [  44  510  897  927 1048 1243 1328]
# new mcurr:
# [  44  231  510  897  927 1048 1243]
# finished iter: 3
# finished iter: 4
# finished iterative phase...
# Finished runs...
# Pearson correlation: nan
# C:\Users\Ingenieur\Anaconda2\lib\site-packages\scipy\stats\stats.py:3038: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# C:\Users\Ingenieur\Anaconda2\lib\site-packages\scipy\stats\stats.py:3047: RuntimeWarning: invalid value encountered in double_scalars
#   t_squared = r**2 * (df / ((1.0 - r) * (1.0 + r)))
